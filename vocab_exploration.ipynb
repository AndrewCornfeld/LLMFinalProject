# %% [markdown]
# # Find total vocabulary for llm

# %%
#imports 
import pandas as pd
import numpy as np
import re # used in vocab_cleaner

# %%
#read in the csv 
data = pd.read_csv("2deep_output.csv")

# %%
extractedtext = data['ExtractedText'].astype('str')
extractedtext
# Out:
# 0       Stay connected to Grounds no matter where you ...
# 1       Everything is made of something. In Materials ...
# 2       October 20, 2022•By\n\n\t\t\t\t\t             ...
# 3       Learn more about our degree and certificate pr...
# 4                                                     nan
#                               ...
# 1193    A full-time, 21-month curriculum and a global ...
# 1194    Javascript is currently not supported, or is d...
# 1195    In accordance with section 23.1-409 of the Cod...
# 1196    Learn more about our degree and certificate pr...
# 1197    Make a Gift  Before declaring amajor in Sociol...
# Name: ExtractedText, Length: 1198, dtype: object

# %%
#create function to feed in dataset, split all words in each row's response, and output the set of vocabulary in the dataset
def vocab_extractor(dataset, a = 1):
    '''
    This functions gathers the full vocabulary for a given dataset.
    input:
        - dataset - 2 columns, one for links and ExtractedText
    output:
        - vocab - set of unique words in dataset
    '''
    extractedtext = dataset['ExtractedText'].astype('str')
    vocab = []
    #for each row, splits and aggregates the words to the total vocab
    for _,text in enumerate(extractedtext):
        words = text.split()
        vocab.extend(words)
    vocab = set(vocab)
    return vocab

# %%
#run function
vocab = vocab_extractor(data)

# %% [markdown]
# # clean vocabulary

# %%
#create function to parse through vocab and remove things that start/end with punctuation or quotes 
def vocab_cleaner(vocab):
    '''
    need to import re
    This function cleans the punctuation at the beginning or end of words.
    
    input:
       - vocab - a set of unique vocab words
    output:
       - new_vocab - a set of unique vocab words that dont start/end with punction
    '''
    cleaned_vocab = set()
    for word in vocab:
        cleaned = re.sub(r'^\W+|\W+$', '', word)  # remove leading/trailing non-word chars
        if cleaned:  # skip empty strings
            cleaned_vocab.add(cleaned)
    return cleaned_vocab

# %%
new_vocab = vocab_cleaner(vocab)
new_vocab
# Out:
# {'in-state',
#  'Variants',
#  'Wingfield',
#  'publication',
#  'ProgramsBA',
#  'ENROLLMENT',
#  'AlgebraORMATH',
#  'Aquatics',
#  'problÃ¨mes',
#  'Bernard',
#  'BBCGTransformaÃ§Ã£o',
#  'LectureBiology',
#  'AirbnbÂ',
#  'CoursesESL',
#  'transcriptthrough',
#  'WorkshopEvolutionary',
#  'Battery15',
#  'referee',
#  'atcharlottesville@solidcore.coto',
#  '3180',
#  'passage',
#  'transcend',
#  '繁體中文',
#  'nothing',
#  'discontinue',
#  'linkedin',
#  'suitability',
#  'Ð¾Ð´Ð¸Ñ',
#  'ofResearch',
#  'APPLICANTSMASTER',
#  'ourGift',
#  'hotel/conference',
#  'doctrine',
#  'Amount',
#  'deprive',
#  'Clean',
#  'what’s',
#  'likely',
#  'CatholicismCredits',
#  'pertinence',
#  'modeled',
#  'physician’s',
#  'entwerfenâ\x80¢1',
#  'dietary',
#  'afetam',
#  'Overviewguide',
#  'gymnasium',
#  'High-temperature',
#  '2025Forging',
#  'outcomes.PROGRAM',
#  'Ã©tÃ',
#  'summer.certificatecollege-of-arts-and-sciencesschool-of-continuing-amp-amp-professional-studiesarts-and-humanities',
#  'entered',
#  'Institute',
#  'SIS)for',
#  'linear',
#  'walk',
#  'IBMâ\x80¢14',
#  'seguida',
#  'meaningfully',
#  'быть.coursedarden-school-of-businessbusiness',
#  'Revised',
#  'automation',
#  'ØªÙ\x82Ù\x88Ø',
#  'Printer',
#  'Roadway',
#  'SectionGo',
#  'Learningâ\x80¢10',
#  'Grading',
#  'Planningâ\x80¢1',
#  'restrooms',
#  'EventsAdmissions',
#  'Tecnologias',
#  'PlanningResearch',
#  'Project?â\x80¢5',
#  '1947-1959',
#  'Ø±Ø¦Ù\x8aØ³Ù\x8aØ',
#  'CalendarExam',
#  'felony',
#  'la',
#  'Staley',
#  '3920',
#  'pose',
#  '2061',
#  'dualidad',
#  '2.1-341.1',
#  'Ø®Ø§ØªÙ',
#  'List',
#  'Glad',
#  'methodology',
#  'argument',
#  'Virginia.courseschool-of-medicinemedicine-and-health-sciences',
#  'â\x80\x9ezu',
#  '2.2-3800et',
#  'DissertationsDiversity',
#  'Distinguished',
#  'www.charlottesvillehearing.com',
#  '22903',
#  'editor',
#  'lâ\x80\x99Ã©chelle',
#  'entre',
#  "semester's",
#  'c.756',
#  'ejemplos',
#  'GAA)between',
#  'onto',
#  'POL',
#  'culturally',
#  'JourneysSearchSearch',
#  'Shared',
#  '24.2',
#  'riverine',
#  'pursued',
#  'well-prepared',
#  'fournisseursâ\x80¢5',
#  'forced',
#  'Ð¾Ñ\x81Ð½Ð¾Ð²Ð°Ð¼',
#  'family',
#  'Valueâ\x80¢10',
#  'Multimedia',
#  '434.284.4422',
#  'genau',
#  'avant/aprÃ¨sÂ',
#  'Universities',
#  'buildingwhich',
#  'mix',
#  'await',
#  'resume',
#  'Management(BPHM',
#  'extremes',
#  '18.2-340.15et',
#  'tight-knit',
#  'instantaneous',
#  'Ø¨Ø§Ù\x84Ø¶Ø¨Ø·Ø',
#  'insecurities',
#  'Curious',
#  'SeminarGraduate',
#  'Rencontrer',
#  'StaffPostdoctoral',
#  'whodunit',
#  'Ø§Ù\x84Ù\x81Ø±Øµ',
#  'professors',
#  'Ð°ÐºÑ\x82Ð¸Ð²Ñ',
#  'Technikerâ\x80¢5',
#  'BusinessHoy',
#  'talks',
#  'commitment',
#  'CinemaCredits',
#  'Reportâ\x80¢3',
#  'StudentsStaffMentor',
#  'China',
#  'anatomy',
#  'Drude',
#  'Pulmonary',
#  'ausmachen',
#  'Arthur',
#  'Tricuspid',
#  'conspicuously',
#  'examination',
#  'applicant’s',
#  'nexuses—Creativity',
#  'Lichtenstein',
#  'non-academic',
#  'necesitas',
#  'rivers',
#  'Motion',
#  'show’s',
#  'CampusWGS',
#  'Blake',
#  'clipboards',
#  'AnÃ¡lisis',
#  'owners',
#  'Less',
#  'Ñ\x80Ð°Ð·Ñ\x80Ð°Ð±Ð¾Ñ\x82Ð°Ð½Ð½Ð¾Ð¼',
#  '22903Phone:(434',
#  'passport',
#  'SEP',
#  'Each',
#  'DTâ\x80¢6',
#  'Knowledge',
#  'handy',
#  'AmÃ©liorer',
#  '3505',
#  'SystemsCredits',
#  'ASDs',
#  'Skala',
#  'envision',
#  'preparation',
#  'Suchak',
#  'TOEFL',
#  'PresÃ©ntateâ\x80¢10',
#  '2419',
#  'Achieving',
#  'Battery',
#  'GPCGPC',
#  'processions',
#  'hr.virginia.edu/wellness',
#  '2260',
#  'stating',
#  'â\x80\x9ccertificationâ',
#  '2.2-2237.1regarding',
#  'Institutionally',
#  'Positions',
#  'Experience',
#  'ScienceDeep',
#  'Committees',
#  '1â\x80¢2',
#  'Sanju',
#  'LANGUAGES',
#  'ciÃªncia',
#  'Attn',
#  '149',
#  'pode',
#  '800832',
#  'Clothing',
#  'bus',
#  'companioncan',
#  'LabArchivesNew',
#  'deficiencies',
#  'mayauditwith',
#  '3525',
#  '520',
#  'Unbeknownst',
#  'Venetian',
#  'noxious',
#  'rÃ©union',
#  'Journeyâ\x80¢9',
#  'Cycleâ\x80¢2',
#  'Portfolioâ\x80¢0',
#  'Ð\x9aÐ¾Ð½ÐºÑ\x83Ñ\x80ÐµÐ½Ñ\x82Ð½Ñ\x8bÐµ',
#  'PO?â\x80¢8',
#  'PHONE:434-243-5636',
#  'Forgiveness',
#  'Cannulation',
#  'books',
#  'mainstays',
#  'Schools',
#  'same',
#  'CTU',
#  'Processâ\x80¢3',
#  'doesnotreducethe',
#  'coloring',
#  'trabalhavam',
#  'self-enroll',
#  'expensive',
#  'commonly',
#  '263',
#  'Database',
#  'Heidi',
#  'Cohort',
#  'deductions',
#  'StudentsAuditoriumFacilitiesSpaces',
#  'protected',
#  '54,479already',
#  'vu',
#  'Leake',
#  'wants',
#  'Submitting',
#  'coalition',
#  'Notification',
#  'executes',
#  'significa?coursedarden-school-of-businessbusiness',
#  'ØµÙ',
#  'DHE)Division',
#  'TraditionCredits',
#  'Servicesat',
#  'iterate',
#  'Associates',
#  'Ð´ÐµÐ½Ñ',
#  'Hidden',
#  'because',
#  'vibrant',
#  'comprensiÃ³n',
#  'network-related',
#  'OperationsCourse',
#  'mcf7sc@virginia.edu',
#  'bejointly',
#  'atualmente',
#  'EventsAlumni',
#  'PPL',
#  'succession',
#  'Veremos',
#  'Recipients',
#  'comprised',
#  'venues',
#  'EnvironmentPhD',
#  'Reassessing',
#  'Yahoo',
#  'gender-based',
#  '4,039reviews',
#  'ResourcesOutstanding',
#  'four-year',
#  'Elementary',
#  'Comprehensive',
#  'Ù\x8aÙ\x86Ø´Ø',
#  'won',
#  'AccountReference',
#  'Naturalism',
#  'Â',
#  'tobacco',
#  'Breakeven',
#  'MinorSTS',
#  'Dawkins(Deputy',
#  'FacultyFaculty',
#  'DevelopmentUniversity',
#  'buzz',
#  'ultrasonic',
#  'integrate',
#  'Spallation',
#  'vezes',
#  'CITIES',
#  'dynamic',
#  '2310',
#  'AdmissionsAbout',
#  '4560',
#  'FitnessSmall',
#  'Kennedycoursecollege-of-arts-and-sciencesarts-and-humanities',
#  'council',
#  'MSC',
#  'exports',
#  'Evaluations',
#  'System)The',
#  'clerked',
#  'ProjectsProgram',
#  'more.You',
#  '434-982-3010',
#  'Engages',
#  'Amaka',
#  'Scholarship:This',
#  'archived',
#  'nuestro',
#  'Ø£Ù\x86Ù\x88Ø§Ø¹Ù\x87Ø§Ø',
#  'code.Foot',
#  'firmeneigene',
#  'GarageVirginia',
#  'Ð¸Ð´ÐµÐ',
#  'SafetyDegree',
#  'co-host',
#  'Mowing',
#  'students.Learn',
#  '3401',
#  'ØªÙ\x81Ù\x83Ù\x8aÙ',
#  'theEvent',
#  'DC',
#  'FormsForms',
#  'unclear',
#  'AnatomyCourse',
#  '3.7',
#  'MBAEarn',
#  'Third,we',
#  'addition,24/7',
#  'TheThoughts',
#  'contacts',
#  'https://thecarcarriage.comTopcars',
#  'bank',
#  '15.2-1627.4',
#  'forge',
#  'EdIRB-HSR',
#  'Posthumous',
#  'ÐºÐ¾Ð½Ñ\x82ÐµÐºÑ\x81Ñ',
#  'enthalten',
#  'chart',
#  'performed',
#  'NOTICECONSUMER',
#  'COI',
#  'Ø´Ø±Ù\x88Ø¹Ù',
#  'split',
#  'Ñ\x81Ñ\x82Ñ\x80Ð°Ñ\x82ÐµÐ³Ð¸Ð¸â\x80¢6',
#  'inHow',
#  'Ð¿Ñ\x80ÐµÐ´Ð»Ð¾Ð¶ÐµÐ½Ð¸Ð¹â\x80¢3',
#  'yard',
#  'Kenan',
#  'noteCommunity',
#  'real-world',
#  'Causalityâ\x80¢7',
#  'InfinityFundamentals',
#  'revenusâ\x80¢7',
#  'core',
#  'joint',
#  'Office:485',
#  'Ð²Ð°Ð¶Ð½Ð',
#  'Projektplanung',
#  'Ø§Ù\x84Ø§Ø²Ø¯Ù\x88Ø§Ø¬Ù\x8aØ',
#  'involves',
#  'Ð¾Ñ\x86ÐµÐ½Ð¸Ñ\x82Ñ',
#  'Frac',
#  'Pipelinesâ\x80¢6',
#  'stunned',
#  '6th',
#  'unconditional',
#  'CafeteriaUVA',
#  'AAU)Comparing',
#  'curfew',
#  'amendments',
#  'Airportâ\x80¢10',
#  'ill',
#  'cry',
#  'Transnational/Diaspora',
#  'ferramentas',
#  'researchpaper',
#  'Health)800.331.6483|ticketsatwork.com',
#  'WellAWARE',
#  '33.2-1820or56-575.17notwithstanding',
#  'false',
#  'doubt',
#  'puts',
#  'grasp',
#  'two-year',
#  '924-3793',
#  'representation',
#  'All-American',
#  'Pruebas',
#  'ofStudent',
#  'ResourcesMove-In',
#  'Ñ\x80ÐµÑ\x88ÐµÐ½Ð¸Ñ',
#  'creatively',
#  'Made',
#  'commissioning',
#  'Record',
#  '2022•By',
#  'responder',
#  'ProjectsNorth',
#  'Lecturers',
#  'address',
#  'Tamika',
#  'Additional',
#  'Resignation',
#  'dicen',
#  'metal',
#  'allowing',
#  'Ð¢ÐµÐ¿ÐµÑ\x80Ñ',
#  'RDS',
#  'https://madabolic.com/va/charlottesville',
#  'gemeinsame',
#  'African-American',
#  'rwf6v@virginia.edu',
#  'Work-Study',
#  'like',
#  'onlineFall',
#  'SystemsFall',
#  'Burns',
#  '1:Grab',
#  'OpponentsHall',
#  'Spain',
#  'UG',
#  'navy-blue',
#  'multidimensional',
#  'Mezcal',
#  'northeastern',
#  'Customizable',
#  '434.443.5706',
#  'Ø¨Ø§Ø³ØªØ®Ø¯Ø§Ù',
#  'interpretation',
#  'approached',
#  'Interconnection',
#  'ØªØºÙ\x8aØ±Ø§Øªâ\x80¢6',
#  'Spangler',
#  'GrÃ¼nde',
#  'ProgramGraduate',
#  'oxymetazoline',
#  'Lukas',
#  'finances',
#  'RetiVue',
#  'situations',
#  'Eyebobs',
#  'TOEFL/IELTS',
#  'LinksInvite',
#  'Ù\x88Ø³Ù\x86Ø®ØªÙ',
#  'AstronomyGraduate',
#  'Zhigilei(434',
#  '15310',
#  'Prospects',
#  'Ð\x94Ð¸Ð·Ð°Ð¹Ð½-Ð¼Ñ\x8bÑ\x88Ð»ÐµÐ½Ð¸ÐµÂ',
#  'messageto',
#  'TheMastercard',
#  'panelFebruary',
#  '297-8026',
#  'InitiativesGraduation',
#  'meilleures',
#  'thus',
#  'surrounded',
#  'Co-Vice',
#  'deny',
#  'theBACS',
#  'diagnose',
#  'стали',
#  'mitral',
#  'Quizâ\x80¢20',
#  'throughUVA',
#  'Secours',
#  '80.05',
#  'Hourevent',
#  'crecimiento',
#  'gardeÂ',
#  'Institutions»Subtitle',
#  'administrations',
#  'Destinations',
#  'StudentsOverviewBicentennial',
#  'ayudarÃ¡n',
#  'siblings',
#  'petitioner',
#  'abuse',
#  'Doâ\x80¢4',
#  'Clemons',
#  'industry',
#  'ØªØ¬Ù\x86Ø',
#  'university’s',
#  'Grill',
#  'behalf',
#  'disponÃ\xadveis',
#  'visitors.See',
#  'Theoryâ\x80¢21',
#  'Market-based',
#  'statistic',
#  'ideas.coursedarden-school-of-businessbusiness',
#  '1602',
#  '2.2-4019or2.2-4020during',
#  'sans',
#  'Intermediate',
#  'Ancestors',
#  'prowess',
#  'SciencesMasses',
#  'slide',
#  '434.295.3121',
#  'AssetsRecovery',
#  'division',
#  'announcements',
#  'Millia',
#  'PolicyCourse',
#  'BenefitsandNew',
#  'today’s',
#  'stick',
#  'Kritzer',
#  'Purpose',
#  'fabrication—and',
#  'Pursue',
#  'muitas',
#  'CertificatesDNPPhDGlobal',
#  'Ù\x84Ù\x84ØªØ·Ù\x88Ù\x91Ø',
#  'acuerdo',
#  'Weather',
#  'monolÃ\xadticas',
#  'Ñ\x86ÐµÐ½Ð½Ñ\x8bÑ',
#  'Ñ\x86ÐµÐ¿Ð»Ñ\x8fÐµÑ\x82?Â',
#  'Challengesand',
#  'requestTeaching',
#  'information:identification',
#  'Venturing',
#  'Scuba',
#  'fÃ¼hrt',
#  'Cooley',
#  'bewerten',
#  'helpful',
#  'Mom:You',
#  'golden',
#  'small',
#  'easier',
#  'Kean',
#  'Laurent',
#  'Positionâ\x80¢180',
#  'â\x80\x9ce',
#  '3.4',
#  'hinder',
#  'attempt',
#  "wasn't",
#  'beste?â\x80¢5',
#  'AssuranceFWA#:00006183Exp',
#  'Historical',
#  'bekannt',
#  'Ð\x94ÐµÐ¼Ð¾',
#  'Guy',
#  '5170',
#  'Flip',
#  'rely',
#  'nominee',
#  'BIOC',
#  'Steeves',
#  'tax-related',
#  'Ihrer',
#  'masses',
#  'As',
#  'research—everything',
#  '1969',
#  '434.688.4482',
#  'currency):Bank',
#  'seagrass',
#  'Poplar',
#  '800-1000-word',
#  'acoustics',
#  'ItalyCredits',
#  '3600',
#  'assays',
#  'thoughtfulness',
#  'tausend',
#  'One-on-one',
#  'TachycardiaCourse',
#  'associations',
#  'valued',
#  'fairly',
#  'PMEmotional',
#  'poco',
#  'Zunder',
#  'BusinessInnovating',
#  'OUR',
#  'Prehistory',
#  'inovaÃ§Ã£oâ\x80¢18',
#  'process.courseschool-of-medicinemedicine-and-health-sciences',
#  'usted?â\x80¢3',
#  'Ð\x9dÐ',
#  'equipment',
#  'uncommon',
#  'Conde',
#  'met—say',
#  'Advaray',
#  '71.1',
#  'transferring',
#  '29)Nazirah',
#  'Crisman',
#  '12:30',
#  'LachProfessor',
#  'programmaycount',
#  'CommunicationsPresentation',
#  'custodial',
#  '8am-5pm',
#  'BusinessIntroduction',
#  'if',
#  '4824',
#  'frustrating',
#  'directly',
#  'Priorities434.924.1452|mdm6bt@virginia.eduCharlottesvilleVA22904',
#  'Ð´ÐµÐ¹Ñ\x81Ñ\x82Ð²ÐµÐ½Ð½Ð¾Ð¹',
#  'Losses',
#  'Orthotic',
#  '24-hour',
#  'Shannon',
#  'Karlin',
#  'Dans',
#  'asÃ',
#  'penser',
#  'Informed',
#  'May64:30',
#  'Ø¨ØªØ²Ø§Ù\x8aØ',
#  'Performing',
#  'feein',
#  'facilities',
#  'SciencesRecognizing',
#  'CatalogHow',
#  'Ù\x86Ø³ØªØ®Ø¯Ù',
#  'Studies1001',
#  'Willis',
#  '800.968.5844',
#  'classifications',
#  'catheter',
#  'fight',
#  "Let's",
#  'Islands',
#  'psychiatric',
#  'Processesâ\x80¢10',
#  'pleaseexport',
#  'Die',
#  'moteurs',
#  'AbroadClassics',
#  'LeadersCredits',
#  'feels',
#  'LabJefferson',
#  '91',
#  'Influence/Impact',
#  '6,413',
#  'Rehnquist',
#  'chapters',
#  'folk',
#  'procedures',
#  'withrecord',
#  'pancreasthat',
#  'Arab',
#  'Aid,Princeton',
#  'submitted',
#  'retenez-vous',
#  'ISSP',
#  'aperÃ§u',
#  'Graduating',
#  'extend',
#  'Positionierung',
#  'Preparation(Noncredit',
#  'obtainedbeforetaking',
#  'Easily',
#  'invention',
#  'casting',
#  'genomics-based',
#  'Beauty',
#  'Intelligenz',
#  'AplicaciÃ³n',
#  '252-258',
#  'Ñ\x83Ð¶Ðµ',
#  'Ã¤uÃ\x9feren',
#  'outbreak',
#  'Ð¿ÐµÑ\x80ÐµÑ\x81Ñ\x82Ñ\x80Ð°Ð¸Ð²Ð°Ñ\x82Ñ',
#  "DON'T",
#  'Holiday',
#  'Ø§Ù\x84Ø´Ø§Ø¦Ø¹Ø©â\x80¢9',
#  'Encourage',
#  'Starship',
#  'USEMs',
#  'rÃ©ussiteCourse',
#  'forget',
#  'CarrieJordanDirector',
#  'unseren',
#  'ClinicalClinical',
#  'strengthen',
#  'BankCapCenterZero',
#  'Ø¨ØªØ·Ø¨Ù\x8aÙ',
#  '33132',
#  'fracasando',
#  'Co$1',
#  'CHARITABLE',
#  'Cleeves',
#  '22902434.529.3300',
#  '403(b',
#  'desarrollado',
#  'Rotichto',
#  'unaccompanied',
#  'disparate',
#  '3â\x80¢1',
#  'Ø²Ù',
#  'introduced',
#  'Light',
#  'froze',
#  'aptitude',
#  'de',
#  'SchoolFoundations',
#  'Afro-American',
#  'HTMLâ\x80¢7',
#  'StudentsProgram',
#  'Fair',
#  'civic',
#  '434.979.2009',
#  'Definition',
#  'VSUDr',
#  'StudentsTransfer',
#  'Mechanobiology',
#  'cancel',
#  'Nephrology',
#  'responding',
#  'translate',
#  '3671',
#  'sounded',
#  'CoursesGraduate',
#  'TAKING',
#  'dirt',
#  'stars75.21',
#  '2â\x80¢3',
#  'MedicineCardiac',
#  'alineados',
#  'criteria',
#  'FinancialFree',
#  'Despina',
#  'S/Lee',
#  'Mid-level',
#  'coordinators',
#  'EntwicklungÂ',
#  'high-quality',
#  'T5â\x80¢10',
#  'MedicineFamily',
#  'Ð´Ð¸Ð·Ð°Ð¹Ð½-Ð¼Ñ\x8bÑ\x88Ð»ÐµÐ½Ð¸Ñ',
#  '520-seat',
#  'Ð±Ð¾Ð»ÐµÐµ',
#  'Security:434-243-5636',
#  'rates.While',
#  'Student',
#  'Admission:Complete',
#  'PresidentAddress',
#  '257',
#  '3887',
#  'Algo',
#  'producing',
#  'Epics',
#  'Hypothesis',
#  "d'excellents",
#  'problems.cardinal-educationdegreeschool-of-engineering-and-applied-scienceengineering-and-science',
#  'Togetherâ\x80¢4',
#  'EngagementAvailable',
#  'democracies',
#  'Otolaryngology',
#  'andsix',
#  'newcomers',
#  'brought',
#  'nor',
#  'Grammar',
#  'Mohr',
#  'Ñ\x81Ñ\x82Ñ\x80Ð°Ñ\x82ÐµÐ³Ð¸Ð',
#  'incredible',
#  'Ø¯Ù\x81Ø¹',
#  'Ð¿Ñ\x80Ð¸Ñ\x88Ð»Ð',
#  'number.Your',
#  'Ñ\x81Ð¾Ð±Ñ\x81Ñ\x82Ð²ÐµÐ½Ð½Ñ\x83Ñ',
#  'adapt',
#  'billion',
#  'once?How',
#  'fatalitÃ',
#  'Managementâ\x80¢13',
#  'enroll',
#  'Ø§Ù\x84Ø¥Ø¨Ø¯Ø§Ø¹Ø',
#  'www.successstudiopt.comBrooks',
#  'subtler',
#  'LaborCredits',
#  'Ð\x94Ð¾Ð±Ñ\x80Ð¾',
#  'UnfallchirurgieCourse',
#  'well-paying',
#  'bio',
#  'hÃ´tes',
#  "student's",
#  'hesitate',
#  'Brown,School',
#  'intends',
#  'evasions',
#  'processes',
#  'contextually',
#  'Rights,Equal',
#  'Infographic',
#  'coÃ»tsÂ',
#  'MedicineDiagnosis',
#  'giftIndependent',
#  'wherever',
#  '4040',
#  'humans',
#  'Ultrasounds',
#  'LessonsWellness',
#  'dysfunction',
#  'cela',
#  'EEB',
#  'sure',
#  'Ð»Ñ\x8eÐ´ÐµÐ¹',
#  '76.68',
#  'coverage',
#  'Ereignisse',
#  'corporativo',
#  'LIE',
#  'ØµÙ\x84Ø\xadØ',
#  '40pt',
#  'title“UVACOLLAB',
#  'aircraft',
#  'ResourcesFellows',
#  'nanoscience',
#  'accompany',
#  'investor',
#  'authentication',
#  'Ñ\x80Ð°Ð½Ð½ÐµÐ¼',
#  'concern',
#  'Tennis',
#  'sort',
#  'Mars',
#  "MasAgro's",
#  'stars3.96',
#  'Ð¸Ñ\x81Ñ\x82Ð¾Ñ\x80Ð¸Ð¹',
#  'quizzes',
#  'Penser',
#  'CVT',
#  'thesemustbe',
#  '57th',
#  'Austin',
#  'undergraduate-level',
#  'Boundaries',
#  'non-virginia.edu',
#  '2.2-3705.3related',
#  'available.Visit',
#  'Commerce,School',
#  'approved',
#  'room',
#  'repensé',
#  'addressingALLResearch',
#  'men',
#  '25.42',
#  'Ð¸Ð½Ð½Ð¾Ð²Ð°Ñ\x86Ð¸Ð¾Ð½Ð½Ð¾Ð¹',
#  'ProcessFinancial',
#  'Rail',
#  'CLVâ\x80¢3',
#  'Probationary',
#  'WGS',
#  'BSCS',
#  'theNorth',
#  'beings',
#  'Japanese',
#  'communicatorcan',
#  'contamination',
#  '15.21',
#  'ends',
#  'Storytelling',
#  'Produktentwicklung',
#  'lightly',
#  'procesar',
#  'Hypothesis-driven',
#  'RELG',
#  'Ð\x98Ñ\x81ÐºÑ\x83Ñ\x81Ñ\x81Ñ\x82Ð²ÐµÐ½Ð½Ñ\x8bÐ¹',
#  'Ø§Ù\x84Ø§Ø³ØªØ´Ø§Ø±Ù\x8aØ',
#  'Appointments',
#  'GeneticsCredits',
#  'Carey',
#  'repertoire',
#  'lvg@virginia.edu',
#  'ÐºÐ¾Ð³Ð´Ð',
#  'pursue',
#  '924-1377',
#  'Baroque',
#  'SoundCourse',
#  'Estrategia',
#  'prospÃ©rer',
#  'often',
#  'deuxiÃ¨me',
#  'hallmark',
#  'complexities',
#  'SEAS-approved',
#  'CoursesBatten',
#  'Segmentâ\x80¢4',
#  'Ã\x96kosystemeâ\x80¢10',
#  'UVACanvas,join',
#  'Individually',
#  'Ø¹Ù\x84Ø§Ù\x88Ø',
#  'Lessonsâ\x80¢3',
#  'Ted',
#  'AboutPeopleCharterAccessibility',
#  'birds',
#  'adds',
#  'pursues',
#  'Odom',
#  'Racism',
#  'Watson',
#  '10,178reviews',
#  'Tkachenko',
#  'attend.Step',
#  'X-ray',
#  '1976',
#  'agileâ\x80¢6',
#  'Ø©â\x80¢9',
#  'produtoâ\x80¢2',
#  'High-Income',
#  'approfondir',
#  's',
#  '924-3021library@virginia.eduUVA',
#  'K-12',
#  'Student-Athlete',
#  'media-related',
#  'Asynchronous',
#  'entraÃ®ne',
#  "DEAN'S",
#  'Chhabra:We',
#  'text-based',
#  'communicating',
#  'HTMLâ\x80¢3',
#  'atÃ',
#  'Action',
#  'judgment.courseschool-of-medicinemedicine-and-health-sciences',
#  'delivers',
#  'work-related',
#  'Canvas.Whenever',
#  'theRare',
#  '1050',
#  'Select',
#  'BusinessGrundlagen',
#  '8-inch',
#  'gradSERU',
#  'gaze',
#  'bestcollegevalues.com',
#  'McIntireMeet',
#  '2,350',
#  'items',
#  'beds',
#  'examine',
#  'multifamily',
#  'StudentsNew',
#  'Costâ\x80¢3',
#  'poignant',
#  'workplace',
#  'DevelopmentToggle',
#  'life',
#  'forms',
#  'greatest',
#  'cream',
#  'ofWwill',
#  'Basik',
#  'lois',
#  'framework',
#  'Learning3.4',
#  'Page2',
#  'ØªØ´ØºÙ\x8aÙ',
#  'ist',
#  'Debaere',
#  'cc.290,778',
#  'PrizeThe',
#  'Diamonds10',
#  'fade',
#  'constant',
#  'Concerns?Please',
#  'reopens',
#  'Citizen',
#  'resource-limited',
#  'Ð°Ð¹Ñ',
#  'testimonials',
#  'StudentsUndergraduate',
#  'Melody',
#  'AwardsChemical',
#  ...}
